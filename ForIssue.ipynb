# %% [markdown]
# <a href="https://colab.research.google.com/github/nabecat1107/hangman/blob/master/ForIssue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
#親の動き
img1= [1000000000000000000000000000000000000000000000000,
       1000000000000000000000000000000000000000000000000,
       1000000000000000000000000000000000000000000000000,
       1011111100000000000000000000000000000000000000000,
       1011111100000000000000000000000000000000000000000,
       1011111100000000000000000000000000000000000000000,
       1000000000000000000000000000000000000000000000000]
#子の動き
img2 = [1000000000000000000000000000000000000000000000000,
        1000000000000000000000000000000000000000000000000,
        1000000000000000000000000000000000000000000000000,
        1000000000000000000000000000000000000000000000000,
        1001111000000000000000000000000000000000000000000,
        1001111000000000000000000000000000000000000000000,
        1000000000000000000000000000000000000000000000000,
        1000000000000000000000000000000000000000000000000]

t = 0

while t < 13:
  x = t // 3
  print(t)
  a = 0
  b = 0

  #tが0,1の時
  if t < 2:
    while a < 6:
      print(img1[a])
      a += 1
    while b < 6:
      print(img2[b])
      b += 1

    a = 0
    b = 0
    while a < 6:
      img1[a] = img1[a] // 10000
      img1[a] = img1[a] + 999900000000000000000000000000000000000000000000
      a += 1

    while b < 6:
      img2[b] = img2[b + 2]
      img2[b] = img2[b] // 10000
      img2[b] = img2[b] + 999900000000000000000000000000000000000000000000
      b += 1


  #tが3,4,5,6,7,8,9,10,...の時
  else:
    while a < 6:
      print(img1[a])
      a += 1
    while b < 7:
      print(img2[b])
      b += 1

    a = 0
    b = 0

    while a < 6:
      img1[a] = img1[a + 1]
      img1[a] = img1[a] // 10000
      img1[a] = img1[a] + 999900000000000000000000000000000000000000000000
      a += 1
    while b < 6:
      img2[b] = img2[b] // 10000
      img2[b] = img2[b] + 999900000000000000000000000000000000000000000000
      b += 1



  #空行入力
  print()

  time.sleep(1)
  t = t + 1
# Out:
# 0
# 1000000000000000000000000000000000000000000000000
# 1000000000000000000000000000000000000000000000000
# 1000000000000000000000000000000000000000000000000
# 1011111100000000000000000000000000000000000000000
# 1011111100000000000000000000000000000000000000000
# 1011111100000000000000000000000000000000000000000
# 1000000000000000000000000000000000000000000000000
# 1000000000000000000000000000000000000000000000000
# 1000000000000000000000000000000000000000000000000
# 1000000000000000000000000000000000000000000000000
# 1001111000000000000000000000000000000000000000000
# 1001111000000000000000000000000000000000000000000
#
# 1
# 1000000000000000000000000000000000000000000000000
# 1000000000000000000000000000000000000000000000000
# 1000000000000000000000000000000000000000000000000
# 1000001111110000000000000000000000000000000000000
# 1000001111110000000000000000000000000000000000000
# 1000001111110000000000000000000000000000000000000
# 1000000000000000000000000000000000000000000000000
# ...
